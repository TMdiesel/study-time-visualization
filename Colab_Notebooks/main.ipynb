# %%
# !pip install jpholiday

# mount
from google.colab import drive 
drive.mount('/content/drive')
# package
import sys
import pathlib
PROJECT_DIR="/content/drive/My Drive/Colab_Notebooks"
sys.path.append(PROJECT_DIR)
import analyze_activity as aa
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
filename="sample.csv"
task_dict= {
    1: "English",
    2: "Coding",
    3: "Math",
    4: "Physics",
    5: "Book",
    }
savename="sample.png"

# %%
filepath=pathlib.Path(PROJECT_DIR)/filename
savepath=pathlib.Path(PROJECT_DIR)/savename
instance=aa.analyze_activitiy(filepath=filepath,task_dict=task_dict,savepath=savepath)
instance.generate_df()
instance.activity_plot()
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
